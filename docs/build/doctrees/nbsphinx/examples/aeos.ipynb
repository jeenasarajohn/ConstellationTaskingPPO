# %% [markdown]
# # Agile Earth-Observing Satellite Environment
#
# This example demonstrates the environment configuration for a power-free and power-constrained agile Earth-observing satellite. These environments reflect the configuration and values from an upcoming journal paper.

# %%
import numpy as np
from Basilisk.architecture import bskLogging
from Basilisk.utilities import orbitalMotion

from bsk_rl import SatelliteTasking, act, data, obs, sats, scene
from bsk_rl.sim import fsw
from bsk_rl.utils.orbital import random_orbit, rv2HN

bskLogging.setDefaultLogLevel(bskLogging.BSK_WARNING)

# %% [markdown]
# ## Power-Free Environment
#
# First, a function for generating satellite types is introduced. This function can generate one of three different observation types, and can choose to include the time through episode in the observation.

# %%
def satellite_generator(observation, n_ahead=32, include_time=False):
    """_summary_

    Args:
        observation: Pick from "S1", "S2", "S3"
        n_ahead: Number of requests to include in the observation and action spaces
        include_time: Whether to include time through episode in the observation
    """

    assert observation in ["S1", "S2", "S3"]

    class CustomSatellite(sats.ImagingSatellite):
        action_spec = [act.Image(n_ahead_image=n_ahead)]
        if observation == "S1":
            observation_spec = [
                obs.SatProperties(
                    dict(prop="omega_BP_P", norm=0.03),
                    dict(prop="c_hat_P"),
                    dict(prop="r_BN_P", norm=orbitalMotion.REQ_EARTH * 1e3),
                    dict(prop="v_BN_P", norm=7616.5),
                ),
                obs.OpportunityProperties(
                    dict(prop="priority"),
                    dict(prop="r_LP_P", norm=orbitalMotion.REQ_EARTH * 1e3),
                    type="target",
                    n_ahead_observe=n_ahead,
                ),
            ]
        elif observation == "S2":
            observation_spec = [
                obs.SatProperties(
                    dict(prop="omega_BH_H", norm=0.03),
                    dict(prop="c_hat_H"),
                    dict(prop="r_BN_P", norm=orbitalMotion.REQ_EARTH * 1e3),
                    dict(prop="v_BN_P", norm=7616.5),
                ),
                obs.OpportunityProperties(
                    dict(prop="priority"),
                    dict(prop="r_LB_H", norm=orbitalMotion.REQ_EARTH * 1e3),
                    type="target",
                    n_ahead_observe=n_ahead,
                ),
            ]
        elif observation == "S3":
            observation_spec = [
                obs.SatProperties(
                    dict(prop="omega_BH_H", norm=0.03),
                    dict(prop="c_hat_H"),
                    dict(prop="r_BN_P", norm=orbitalMotion.REQ_EARTH * 1e3),
                    dict(prop="v_BN_P", norm=7616.5),
                ),
                obs.OpportunityProperties(
                    dict(prop="priority"),
                    dict(prop="r_LB_H", norm=800 * 1e3),
                    dict(prop="target_angle", norm=np.pi / 2),
                    dict(prop="target_angle_rate", norm=0.03),
                    dict(prop="opportunity_open", norm=300.0),
                    dict(prop="opportunity_close", norm=300.0),
                    type="target",
                    n_ahead_observe=n_ahead,
                ),
            ]

        if include_time:
            observation_spec.append(obs.Time())
        fsw_type = fsw.SteeringImagerFSWModel

    return CustomSatellite

# %% [markdown]
# Next, the parameters for the satellite are defined.

# %%
SAT_ARGS = dict(
    imageAttErrorRequirement=0.01,
    imageRateErrorRequirement=0.01,
    batteryStorageCapacity=80.0 * 3600 * 100,
    storedCharge_Init=80.0 * 3600 * 100.0,
    dataStorageCapacity=200 * 8e6 * 100,
    u_max=0.4,
    imageTargetMinimumElevation=np.arctan(800 / 500),
    K1=0.25,
    K3=3.0,
    omega_max=np.radians(5),
    servo_Ki=5.0,
    servo_P=150 / 5,
    oe=lambda: random_orbit(alt=800),
)

# %% [markdown]
# Finally, the environment can be initialized.

# %%
duration = 5700.0 * 5  # 5 orbits
target_distribution = "uniform"
n_targets = 3000
n_ahead = 32

if target_distribution == "uniform":
    targets = scene.UniformTargets(n_targets)
elif target_distribution == "cities":
    targets = scene.CityTargets(n_targets)

env = SatelliteTasking(
    satellite=satellite_generator(observation="S3", n_ahead=32, include_time=False)(
        name="EO1",
        sat_args=SAT_ARGS,
    ),
    scenario=targets,
    rewarder=data.UniqueImageReward(),
    sim_rate=0.5,
    max_step_duration=300.0,
    time_limit=duration,
    failure_penalty=0.0,
    terminate_on_time_limit=True,
    log_level="INFO",
)
_ = env.reset()
for i in range(5):
    env.step(env.action_space.sample())
# Out:
# 2025-02-11 19:12:49,576 gym                            INFO       Resetting environment with seed=655874512
# 2025-02-11 19:12:49,581 scene.targets                  INFO       Generating 3000 targets
# 2025-02-11 19:12:49,743 sats.satellite.EO1             INFO       <0.00> EO1: Finding opportunity windows from 0.00 to 28500.00 seconds
# 2025-02-11 19:12:50,255 gym                            INFO       <0.00> Environment reset
# 2025-02-11 19:12:50,256 gym                            INFO       <0.00> === STARTING STEP ===
# 2025-02-11 19:12:50,256 sats.satellite.EO1             INFO       <0.00> EO1: target index 26 tasked
# 2025-02-11 19:12:50,257 sats.satellite.EO1             INFO       <0.00> EO1: Target(tgt-2418) tasked for imaging
# 2025-02-11 19:12:50,259 sats.satellite.EO1             INFO       <0.00> EO1: Target(tgt-2418) window enabled: 653.6 to 789.9
# 2025-02-11 19:12:50,260 sats.satellite.EO1             INFO       <0.00> EO1: setting timed terminal event at 789.9
# 2025-02-11 19:12:50,336 sim.simulator                  INFO       <300.00> Max step duration reached
# 2025-02-11 19:12:50,339 data.base                      INFO       <300.00> Data reward: {}
# 2025-02-11 19:12:50,340 comm.communication             INFO       <300.00> Optimizing data communication between all pairs of satellites
# 2025-02-11 19:12:50,353 gym                            INFO       <300.00> Step reward: 0.0
# 2025-02-11 19:12:50,355 gym                            INFO       <300.00> === STARTING STEP ===
# 2025-02-11 19:12:50,356 sats.satellite.EO1             INFO       <300.00> EO1: target index 1 tasked
# 2025-02-11 19:12:50,357 sats.satellite.EO1             INFO       <300.00> EO1: Target(tgt-1850) tasked for imaging
# 2025-02-11 19:12:50,359 sats.satellite.EO1             INFO       <300.00> EO1: Target(tgt-1850) window enabled: 243.1 to 361.6
# 2025-02-11 19:12:50,360 sats.satellite.EO1             INFO       <300.00> EO1: setting timed terminal event at 361.6
# 2025-02-11 19:12:50,378 sats.satellite.EO1             INFO       <359.50> EO1: imaged Target(tgt-1850)
# 2025-02-11 19:12:50,382 data.base                      INFO       <359.50> Data reward: {'EO1': 0.6130502671981524}
# 2025-02-11 19:12:50,383 comm.communication             INFO       <359.50> Optimizing data communication between all pairs of satellites
# 2025-02-11 19:12:50,386 sats.satellite.EO1             INFO       <359.50> EO1: Satellite EO1 requires retasking
# 2025-02-11 19:12:50,397 gym                            INFO       <359.50> Step reward: 0.6130502671981524
# 2025-02-11 19:12:50,398 gym                            INFO       <359.50> === STARTING STEP ===
# 2025-02-11 19:12:50,399 sats.satellite.EO1             INFO       <359.50> EO1: target index 10 tasked
# 2025-02-11 19:12:50,399 sats.satellite.EO1             INFO       <359.50> EO1: Target(tgt-2442) tasked for imaging
# 2025-02-11 19:12:50,401 sats.satellite.EO1             INFO       <359.50> EO1: Target(tgt-2442) window enabled: 413.2 to 544.1
# 2025-02-11 19:12:50,402 sats.satellite.EO1             INFO       <359.50> EO1: setting timed terminal event at 544.1
# 2025-02-11 19:12:50,419 sats.satellite.EO1             INFO       <418.00> EO1: imaged Target(tgt-2442)
# 2025-02-11 19:12:50,422 data.base                      INFO       <418.00> Data reward: {'EO1': 0.8306736134071587}
# 2025-02-11 19:12:50,423 comm.communication             INFO       <418.00> Optimizing data communication between all pairs of satellites
# 2025-02-11 19:12:50,427 sats.satellite.EO1             INFO       <418.00> EO1: Satellite EO1 requires retasking
# 2025-02-11 19:12:50,438 gym                            INFO       <418.00> Step reward: 0.8306736134071587
# 2025-02-11 19:12:50,439 gym                            INFO       <418.00> === STARTING STEP ===
# 2025-02-11 19:12:50,439 sats.satellite.EO1             INFO       <418.00> EO1: target index 24 tasked
# 2025-02-11 19:12:50,440 sats.satellite.EO1             INFO       <418.00> EO1: Target(tgt-1258) tasked for imaging
# 2025-02-11 19:12:50,443 sats.satellite.EO1             INFO       <418.00> EO1: Target(tgt-1258) window enabled: 1213.0 to 1348.9
# 2025-02-11 19:12:50,443 sats.satellite.EO1             INFO       <418.00> EO1: setting timed terminal event at 1348.9
# 2025-02-11 19:12:50,521 sim.simulator                  INFO       <718.00> Max step duration reached
# 2025-02-11 19:12:50,524 data.base                      INFO       <718.00> Data reward: {}
# 2025-02-11 19:12:50,524 comm.communication             INFO       <718.00> Optimizing data communication between all pairs of satellites
# 2025-02-11 19:12:50,538 gym                            INFO       <718.00> Step reward: 0.0
# 2025-02-11 19:12:50,539 gym                            INFO       <718.00> === STARTING STEP ===
# 2025-02-11 19:12:50,540 sats.satellite.EO1             INFO       <718.00> EO1: target index 9 tasked
# 2025-02-11 19:12:50,540 sats.satellite.EO1             INFO       <718.00> EO1: Target(tgt-251) tasked for imaging
# 2025-02-11 19:12:50,542 sats.satellite.EO1             INFO       <718.00> EO1: Target(tgt-251) window enabled: 1172.1 to 1222.0
# 2025-02-11 19:12:50,543 sats.satellite.EO1             INFO       <718.00> EO1: setting timed terminal event at 1222.0
# 2025-02-11 19:12:50,616 sim.simulator                  INFO       <1018.00> Max step duration reached
# 2025-02-11 19:12:50,619 data.base                      INFO       <1018.00> Data reward: {}
# 2025-02-11 19:12:50,619 comm.communication             INFO       <1018.00> Optimizing data communication between all pairs of satellites
# 2025-02-11 19:12:50,631 gym                            INFO       <1018.00> Step reward: 0.0

# %% [markdown]
# ## Power-Constrained Environment
#
# The power-constrained environment is like the power-free environment, but with an additional battery management requirement. The satellite has additional observation elements to be able to account for power.
#
# First, the upcoming reward density observation is defined.

# %%
class Density(obs.Observation):
    def __init__(
        self,
        interval_duration=60 * 3,
        intervals=10,
        norm=3,
    ):
        self.satellite: "sats.AccessSatellite"
        super().__init__()
        self.interval_duration = interval_duration
        self.intervals = intervals
        self.norm = norm

    def get_obs(self):
        if self.intervals == 0:
            return []

        self.satellite.calculate_additional_windows(
            self.simulator.sim_time
            + (self.intervals + 1) * self.interval_duration
            - self.satellite.window_calculation_time
        )
        soonest = self.satellite.upcoming_opportunities_dict(types="target")
        rewards = np.array([opportunity.priority for opportunity in soonest])
        times = np.array([opportunities[0][1] for opportunities in soonest.values()])
        time_bins = np.floor((times - self.simulator.sim_time) / self.interval_duration)
        densities = [sum(rewards[time_bins == i]) for i in range(self.intervals)]
        return np.array(densities) / self.norm

# %% [markdown]
# The satellite generator function is then defined, along with some additional observations.

# %%
def wheel_speed_3(sat):
    return np.array(sat.dynamics.wheel_speeds[0:3]) / 630


def s_hat_H(sat):
    r_SN_N = (
        sat.simulator.world.gravFactory.spiceObject.planetStateOutMsgs[
            sat.simulator.world.sun_index
        ]
        .read()
        .PositionVector
    )
    r_BN_N = sat.dynamics.r_BN_N
    r_SB_N = np.array(r_SN_N) - np.array(r_BN_N)
    r_SB_H = rv2HN(r_BN_N, sat.dynamics.v_BN_N) @ r_SB_N
    return r_SB_H / np.linalg.norm(r_SB_H)


def power_sat_generator(n_ahead=32, include_time=False):
    class PowerSat(sats.ImagingSatellite):
        action_spec = [act.Image(n_ahead_image=n_ahead), act.Charge()]
        observation_spec = [
            obs.SatProperties(
                dict(prop="omega_BH_H", norm=0.03),
                dict(prop="c_hat_H"),
                dict(prop="r_BN_P", norm=orbitalMotion.REQ_EARTH * 1e3),
                dict(prop="v_BN_P", norm=7616.5),
                dict(prop="battery_charge_fraction"),
                dict(prop="wheel_speed_3", fn=wheel_speed_3),
                dict(prop="s_hat_H", fn=s_hat_H),
            ),
            obs.OpportunityProperties(
                dict(prop="priority"),
                dict(prop="r_LB_H", norm=800 * 1e3),
                dict(prop="target_angle", norm=np.pi / 2),
                dict(prop="target_angle_rate", norm=0.03),
                dict(prop="opportunity_open", norm=300.0),
                dict(prop="opportunity_close", norm=300.0),
                type="target",
                n_ahead_observe=n_ahead,
            ),
            obs.Eclipse(norm=5700),
            Density(intervals=20, norm=5),
        ]

        if include_time:
            observation_spec.append(obs.Time())

        fsw_type = fsw.SteeringImagerFSWModel

    return PowerSat

# %% [markdown]
# Satellite parameters are also modified for the power-constrained environment.

# %%
SAT_ARGS_POWER = {}
SAT_ARGS_POWER.update(SAT_ARGS)
SAT_ARGS_POWER.update(
    dict(
        batteryStorageCapacity=120.0 * 3600,
        storedCharge_Init=lambda: 120.0 * 3600 * np.random.uniform(0.4, 1.0),
        rwBasePower=20.4,
        instrumentPowerDraw=-10,
        thrusterPowerDraw=-30,
        nHat_B=np.array([0, 0, -1]),
        wheelSpeeds=lambda: np.random.uniform(-2000, 2000, 3),
        desatAttitude="nadir",
    )
)

# %% [markdown]
# Finally, the environment can be initialized.

# %%
duration = 5700.0 * 5  # 5 orbits
target_distribution = "uniform"
n_targets = 3000
n_ahead = 32

if target_distribution == "uniform":
    targets = scene.UniformTargets(n_targets)
elif target_distribution == "cities":
    targets = scene.CityTargets(n_targets)

env = SatelliteTasking(
    satellite=power_sat_generator(n_ahead=32, include_time=False)(
        name="EO1-power",
        sat_args=SAT_ARGS_POWER,
    ),
    scenario=targets,
    rewarder=data.UniqueImageReward(),
    sim_rate=0.5,
    max_step_duration=300.0,
    time_limit=duration,
    failure_penalty=0.0,
    terminate_on_time_limit=True,
    log_level="INFO",
)
_ = env.reset()
for i in range(5):
    env.step(env.action_space.sample())
# Out:
# 2025-02-11 19:12:50,665                                WARNING    Creating logger for new env on PID=58725. Old environments in process may now log times incorrectly.
# 2025-02-11 19:12:50,771 gym                            INFO       Resetting environment with seed=1850347512
# 2025-02-11 19:12:50,772 scene.targets                  INFO       Generating 3000 targets
# 2025-02-11 19:12:50,875 sats.satellite.EO1-power       INFO       <0.00> EO1-power: Finding opportunity windows from 0.00 to 28500.00 seconds
# 2025-02-11 19:12:51,668 gym                            INFO       <0.00> Environment reset
# 2025-02-11 19:12:51,669 gym                            INFO       <0.00> === STARTING STEP ===
# 2025-02-11 19:12:51,670 sats.satellite.EO1-power       INFO       <0.00> EO1-power: target index 31 tasked
# 2025-02-11 19:12:51,670 sats.satellite.EO1-power       INFO       <0.00> EO1-power: Target(tgt-720) tasked for imaging
# 2025-02-11 19:12:51,674 sats.satellite.EO1-power       INFO       <0.00> EO1-power: Target(tgt-720) window enabled: 713.4 to 849.0
# 2025-02-11 19:12:51,674 sats.satellite.EO1-power       INFO       <0.00> EO1-power: setting timed terminal event at 849.0
# 2025-02-11 19:12:51,753 sim.simulator                  INFO       <300.00> Max step duration reached
# 2025-02-11 19:12:51,755 data.base                      INFO       <300.00> Data reward: {}
# 2025-02-11 19:12:51,756 comm.communication             INFO       <300.00> Optimizing data communication between all pairs of satellites
# 2025-02-11 19:12:51,769 gym                            INFO       <300.00> Step reward: 0.0
# 2025-02-11 19:12:51,771 gym                            INFO       <300.00> === STARTING STEP ===
# 2025-02-11 19:12:51,771 sats.satellite.EO1-power       INFO       <300.00> EO1-power: target index 21 tasked
# 2025-02-11 19:12:51,771 sats.satellite.EO1-power       INFO       <300.00> EO1-power: Target(tgt-380) tasked for imaging
# 2025-02-11 19:12:51,773 sats.satellite.EO1-power       INFO       <300.00> EO1-power: Target(tgt-380) window enabled: 1044.7 to 1064.0
# 2025-02-11 19:12:51,774 sats.satellite.EO1-power       INFO       <300.00> EO1-power: setting timed terminal event at 1064.0
# 2025-02-11 19:12:51,850 sim.simulator                  INFO       <600.00> Max step duration reached
# 2025-02-11 19:12:51,852 data.base                      INFO       <600.00> Data reward: {}
# 2025-02-11 19:12:51,853 comm.communication             INFO       <600.00> Optimizing data communication between all pairs of satellites
# 2025-02-11 19:12:51,868 gym                            INFO       <600.00> Step reward: 0.0
# 2025-02-11 19:12:51,869 gym                            INFO       <600.00> === STARTING STEP ===
# 2025-02-11 19:12:51,870 sats.satellite.EO1-power       INFO       <600.00> EO1-power: target index 23 tasked
# 2025-02-11 19:12:51,870 sats.satellite.EO1-power       INFO       <600.00> EO1-power: Target(tgt-491) tasked for imaging
# 2025-02-11 19:12:51,872 sats.satellite.EO1-power       INFO       <600.00> EO1-power: Target(tgt-491) window enabled: 1209.0 to 1319.2
# 2025-02-11 19:12:51,872 sats.satellite.EO1-power       INFO       <600.00> EO1-power: setting timed terminal event at 1319.2
# 2025-02-11 19:12:51,944 sim.simulator                  INFO       <900.00> Max step duration reached
# 2025-02-11 19:12:51,946 data.base                      INFO       <900.00> Data reward: {}
# 2025-02-11 19:12:51,947 comm.communication             INFO       <900.00> Optimizing data communication between all pairs of satellites
# 2025-02-11 19:12:51,960 gym                            INFO       <900.00> Step reward: 0.0
# 2025-02-11 19:12:51,961 gym                            INFO       <900.00> === STARTING STEP ===
# 2025-02-11 19:12:51,961 sats.satellite.EO1-power       INFO       <900.00> EO1-power: target index 7 tasked
# 2025-02-11 19:12:51,962 sats.satellite.EO1-power       INFO       <900.00> EO1-power: Target(tgt-430) tasked for imaging
# 2025-02-11 19:12:51,964 sats.satellite.EO1-power       INFO       <900.00> EO1-power: Target(tgt-430) window enabled: 1030.4 to 1159.4
# 2025-02-11 19:12:51,964 sats.satellite.EO1-power       INFO       <900.00> EO1-power: setting timed terminal event at 1159.4
# 2025-02-11 19:12:51,995 sats.satellite.EO1-power       INFO       <1031.50> EO1-power: imaged Target(tgt-430)
# 2025-02-11 19:12:51,998 data.base                      INFO       <1031.50> Data reward: {'EO1-power': 0.9242777434720524}
# 2025-02-11 19:12:51,998 comm.communication             INFO       <1031.50> Optimizing data communication between all pairs of satellites
# 2025-02-11 19:12:52,000 sats.satellite.EO1-power       INFO       <1031.50> EO1-power: Satellite EO1-power requires retasking
# 2025-02-11 19:12:52,012 gym                            INFO       <1031.50> Step reward: 0.9242777434720524
# 2025-02-11 19:12:52,013 gym                            INFO       <1031.50> === STARTING STEP ===
# 2025-02-11 19:12:52,014 sats.satellite.EO1-power       INFO       <1031.50> EO1-power: target index 7 tasked
# 2025-02-11 19:12:52,014 sats.satellite.EO1-power       INFO       <1031.50> EO1-power: Target(tgt-2645) tasked for imaging
# 2025-02-11 19:12:52,018 sats.satellite.EO1-power       INFO       <1031.50> EO1-power: Target(tgt-2645) window enabled: 1087.7 to 1183.9
# 2025-02-11 19:12:52,021 sats.satellite.EO1-power       INFO       <1031.50> EO1-power: setting timed terminal event at 1183.9
# 2025-02-11 19:12:52,044 sats.satellite.EO1-power       INFO       <1089.00> EO1-power: imaged Target(tgt-2645)
# 2025-02-11 19:12:52,047 data.base                      INFO       <1089.00> Data reward: {'EO1-power': 0.4788508594287749}
# 2025-02-11 19:12:52,047 comm.communication             INFO       <1089.00> Optimizing data communication between all pairs of satellites
# 2025-02-11 19:12:52,050 sats.satellite.EO1-power       INFO       <1089.00> EO1-power: Satellite EO1-power requires retasking
# 2025-02-11 19:12:52,062 gym                            INFO       <1089.00> Step reward: 0.4788508594287749
